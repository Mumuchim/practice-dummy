# %%
test = input("Enter something: ")
    print("You entered:", test)
except SyntaxError:
    print("There was a syntax error in your input.")
# Out:
#   Cell In[3], line 1
#     try = input("Enter something: "):
#         ^
# SyntaxError: expected ':'
